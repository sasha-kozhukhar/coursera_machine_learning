# %%
# Нормализация данных для метода ближайших соседей.
# Обычно это делается путем вычитания среднего значения признака и деления на стандартное отклонение.
import numpy as np
import pandas
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import KFold, cross_val_score

# %%
# Парсинг данных
data = pandas.read_csv('wine.data')
data.head()
clsf = data["Class"].tolist()

del data["Class"]
par = [x[1].tolist() for x in data.iterrows()]

# Генератор разбиений делает 5 дровленых сэмлов с перемешанными данными
kf = KFold(178, n_folds = 5, shuffle = True, random_state=42)
len(kf)
print(kf)
# Out:
# sklearn.cross_validation.KFold(n=178, n_folds=5, shuffle=True, random_state=42)

# %%
# k = [1:50] обученные классификации
n1 = KNeighborsClassifier(n_neighbors=1).fit(par, clsf)
n2 = KNeighborsClassifier(n_neighbors=2).fit(par, clsf)
n3 = KNeighborsClassifier(n_neighbors=3).fit(par, clsf)
n4 = KNeighborsClassifier(n_neighbors=4).fit(par, clsf)
n5 = KNeighborsClassifier(n_neighbors=5).fit(par, clsf)
n6 = KNeighborsClassifier(n_neighbors=6).fit(par, clsf)
n7 = KNeighborsClassifier(n_neighbors=7).fit(par, clsf)
n8 = KNeighborsClassifier(n_neighbors=8).fit(par, clsf)
n9 = KNeighborsClassifier(n_neighbors=9).fit(par, clsf)
n10 = KNeighborsClassifier(n_neighbors=10).fit(par, clsf)
n11 = KNeighborsClassifier(n_neighbors=11).fit(par, clsf)
n12 = KNeighborsClassifier(n_neighbors=12).fit(par, clsf)
n13 = KNeighborsClassifier(n_neighbors=13).fit(par, clsf)
n14 = KNeighborsClassifier(n_neighbors=14).fit(par, clsf)
n15 = KNeighborsClassifier(n_neighbors=15).fit(par, clsf)
n16 = KNeighborsClassifier(n_neighbors=16).fit(par, clsf)
n17 = KNeighborsClassifier(n_neighbors=17).fit(par, clsf)
n18 = KNeighborsClassifier(n_neighbors=18).fit(par, clsf)
n19 = KNeighborsClassifier(n_neighbors=19).fit(par, clsf)
n20 = KNeighborsClassifier(n_neighbors=20).fit(par, clsf)
n21 = KNeighborsClassifier(n_neighbors=21).fit(par, clsf)
n22 = KNeighborsClassifier(n_neighbors=22).fit(par, clsf)
n23 = KNeighborsClassifier(n_neighbors=23).fit(par, clsf)
n24 = KNeighborsClassifier(n_neighbors=24).fit(par, clsf)
n25 = KNeighborsClassifier(n_neighbors=25).fit(par, clsf)
n26 = KNeighborsClassifier(n_neighbors=26).fit(par, clsf)
n27 = KNeighborsClassifier(n_neighbors=27).fit(par, clsf)
n28 = KNeighborsClassifier(n_neighbors=28).fit(par, clsf)
n29 = KNeighborsClassifier(n_neighbors=29).fit(par, clsf)
n30 = KNeighborsClassifier(n_neighbors=30).fit(par, clsf)
n31 = KNeighborsClassifier(n_neighbors=31).fit(par, clsf)
n32 = KNeighborsClassifier(n_neighbors=32).fit(par, clsf)
n33 = KNeighborsClassifier(n_neighbors=33).fit(par, clsf)
n34 = KNeighborsClassifier(n_neighbors=34).fit(par, clsf)
n35 = KNeighborsClassifier(n_neighbors=35).fit(par, clsf)
n36 = KNeighborsClassifier(n_neighbors=36).fit(par, clsf)
n37 = KNeighborsClassifier(n_neighbors=37).fit(par, clsf)
n38 = KNeighborsClassifier(n_neighbors=38).fit(par, clsf)
n39 = KNeighborsClassifier(n_neighbors=39).fit(par, clsf)
n40 = KNeighborsClassifier(n_neighbors=40).fit(par, clsf)
n41 = KNeighborsClassifier(n_neighbors=41).fit(par, clsf)
n42 = KNeighborsClassifier(n_neighbors=42).fit(par, clsf)
n43 = KNeighborsClassifier(n_neighbors=43).fit(par, clsf)
n44 = KNeighborsClassifier(n_neighbors=44).fit(par, clsf)
n45 = KNeighborsClassifier(n_neighbors=45).fit(par, clsf)
n46 = KNeighborsClassifier(n_neighbors=46).fit(par, clsf)
n47 = KNeighborsClassifier(n_neighbors=47).fit(par, clsf)
n48 = KNeighborsClassifier(n_neighbors=48).fit(par, clsf)
n49 = KNeighborsClassifier(n_neighbors=49).fit(par, clsf)
n50 = KNeighborsClassifier(n_neighbors=50).fit(par, clsf)

# %%
# Кроссвалидация

print('1 ',round(np.mean(cross_val_score(n1, par, clsf, cv=kf)), 2))
print('2 ',round(np.mean(cross_val_score(n2, par, clsf, cv=kf)), 2))
print('3 ',round(np.mean(cross_val_score(n3, par, clsf, cv=kf)), 2))
print('4 ',round(np.mean(cross_val_score(n4, par, clsf, cv=kf)), 2))
print('5 ',round(np.mean(cross_val_score(n5, par, clsf, cv=kf)), 2))
print('6 ',round(np.mean(cross_val_score(n6, par, clsf, cv=kf)), 2))
print('7 ',round(np.mean(cross_val_score(n7, par, clsf, cv=kf)), 2))
print('8 ',round(np.mean(cross_val_score(n8, par, clsf, cv=kf)), 2))
print('9 ',round(np.mean(cross_val_score(n9, par, clsf, cv=kf)), 2))
print('10 ',round(np.mean(cross_val_score(n10, par, clsf, cv=kf)), 2))
print('11 ',round(np.mean(cross_val_score(n11, par, clsf, cv=kf)), 2))
print('12 ',round(np.mean(cross_val_score(n12, par, clsf, cv=kf)), 2))
print('13 ',round(np.mean(cross_val_score(n13, par, clsf, cv=kf)), 2))
print('14 ',round(np.mean(cross_val_score(n14, par, clsf, cv=kf)), 2))
print('15 ',round(np.mean(cross_val_score(n15, par, clsf, cv=kf)), 2))
print('16 ',round(np.mean(cross_val_score(n16, par, clsf, cv=kf)), 2))
print('17 ',round(np.mean(cross_val_score(n17, par, clsf, cv=kf)), 2))
print('18 ',round(np.mean(cross_val_score(n18, par, clsf, cv=kf)), 2))
print('19 ',round(np.mean(cross_val_score(n19, par, clsf, cv=kf)), 2))
print('20 ',round(np.mean(cross_val_score(n20, par, clsf, cv=kf)), 2))
print('21 ',round(np.mean(cross_val_score(n21, par, clsf, cv=kf)), 2))
print('22 ',round(np.mean(cross_val_score(n22, par, clsf, cv=kf)), 2))
print('23 ',round(np.mean(cross_val_score(n23, par, clsf, cv=kf)), 2))
print('24 ',round(np.mean(cross_val_score(n24, par, clsf, cv=kf)), 2))
print('25 ',round(np.mean(cross_val_score(n25, par, clsf, cv=kf)), 2))
print('26 ',round(np.mean(cross_val_score(n26, par, clsf, cv=kf)), 2))
print('27 ',round(np.mean(cross_val_score(n27, par, clsf, cv=kf)), 2))
print('28 ',round(np.mean(cross_val_score(n28, par, clsf, cv=kf)), 2))
print('29 ',round(np.mean(cross_val_score(n29, par, clsf, cv=kf)), 2))
print('30 ',round(np.mean(cross_val_score(n30, par, clsf, cv=kf)), 2))
print('31 ',round(np.mean(cross_val_score(n31, par, clsf, cv=kf)), 2))
print('32 ',round(np.mean(cross_val_score(n32, par, clsf, cv=kf)), 2))
print('33 ',round(np.mean(cross_val_score(n33, par, clsf, cv=kf)), 2))
print('34 ',round(np.mean(cross_val_score(n34, par, clsf, cv=kf)), 2))
print('35 ',round(np.mean(cross_val_score(n35, par, clsf, cv=kf)), 2))
print('36 ',round(np.mean(cross_val_score(n36, par, clsf, cv=kf)), 2))
print('37 ',round(np.mean(cross_val_score(n37, par, clsf, cv=kf)), 2))
print('38 ',round(np.mean(cross_val_score(n38, par, clsf, cv=kf)), 2))
print('39 ',round(np.mean(cross_val_score(n39, par, clsf, cv=kf)), 2))
print('40 ',round(np.mean(cross_val_score(n40, par, clsf, cv=kf)), 2))
print('41 ',round(np.mean(cross_val_score(n41, par, clsf, cv=kf)), 2))
print('42 ',round(np.mean(cross_val_score(n42, par, clsf, cv=kf)), 2))
print('43 ',round(np.mean(cross_val_score(n43, par, clsf, cv=kf)), 2))
print('44 ',round(np.mean(cross_val_score(n44, par, clsf, cv=kf)), 2))
print('45 ',round(np.mean(cross_val_score(n45, par, clsf, cv=kf)), 2))
print('46 ',round(np.mean(cross_val_score(n46, par, clsf, cv=kf)), 2))
print('47 ',round(np.mean(cross_val_score(n47, par, clsf, cv=kf)), 2))
print('48 ',round(np.mean(cross_val_score(n48, par, clsf, cv=kf)), 2))
print('49 ',round(np.mean(cross_val_score(n49, par, clsf, cv=kf)), 2))
print('50 ',round(np.mean(cross_val_score(n50, par, clsf, cv=kf)), 2))
# Out:
# 1  0.73
# 2  0.66
# 3  0.71
# 4  0.66
# 5  0.67
# 6  0.67
# 7  0.68
# 8  0.68
# 9  0.7
# 10  0.68
# 11  0.7
# 12  0.7
# 13  0.69
# 14  0.68
# 15  0.7
# 16  0.68
# 17  0.7
# 18  0.68
# 19  0.68
# 20  0.69
# 21  0.7
# 22  0.7
# 23  0.7
# 24  0.71
# 25  0.7
# 26  0.7
# 27  0.7
# 28  0.71
# 29  0.71
# 30  0.71
# 31  0.69
# 32  0.71
# 33  0.71
# 34  0.72
# 35  0.72
# 36  0.71
# 37  0.71
# 38  0.71
# 39  0.71
# 40  0.71
# 41  0.71
# 42  0.71
# 43  0.71
# 44  0.71
# 45  0.71
# 46  0.71
# 47  0.7
# 48  0.72
# 49  0.7
# 50  0.71

# %%
# Нормализовала
import sklearn.preprocessing
par1 = np.matrix(par)
stdpar = sklearn.preprocessing.scale(par1, axis=0, with_mean=True, with_std=True)

# %%
# Классифицирую снова
nn1 = KNeighborsClassifier(n_neighbors=1).fit(stdpar, clsf)
nn2 = KNeighborsClassifier(n_neighbors=2).fit(stdpar, clsf)
nn3 = KNeighborsClassifier(n_neighbors=3).fit(stdpar, clsf)
nn4 = KNeighborsClassifier(n_neighbors=4).fit(stdpar, clsf)
nn5 = KNeighborsClassifier(n_neighbors=5).fit(stdpar, clsf)
nn6 = KNeighborsClassifier(n_neighbors=6).fit(stdpar, clsf)
nn7 = KNeighborsClassifier(n_neighbors=7).fit(stdpar, clsf)
nn8 = KNeighborsClassifier(n_neighbors=8).fit(stdpar, clsf)
nn9 = KNeighborsClassifier(n_neighbors=9).fit(stdpar, clsf)
nn10 = KNeighborsClassifier(n_neighbors=10).fit(stdpar, clsf)
nn11 = KNeighborsClassifier(n_neighbors=11).fit(stdpar, clsf)
nn12 = KNeighborsClassifier(n_neighbors=12).fit(stdpar, clsf)
nn13 = KNeighborsClassifier(n_neighbors=13).fit(stdpar, clsf)
nn14 = KNeighborsClassifier(n_neighbors=14).fit(stdpar, clsf)
nn15 = KNeighborsClassifier(n_neighbors=15).fit(stdpar, clsf)
nn16 = KNeighborsClassifier(n_neighbors=16).fit(stdpar, clsf)
nn17 = KNeighborsClassifier(n_neighbors=17).fit(stdpar, clsf)
nn18 = KNeighborsClassifier(n_neighbors=18).fit(stdpar, clsf)
nn19 = KNeighborsClassifier(n_neighbors=19).fit(stdpar, clsf)
nn20 = KNeighborsClassifier(n_neighbors=20).fit(stdpar, clsf)
nn21 = KNeighborsClassifier(n_neighbors=21).fit(stdpar, clsf)
nn22 = KNeighborsClassifier(n_neighbors=22).fit(stdpar, clsf)
nn23 = KNeighborsClassifier(n_neighbors=23).fit(stdpar, clsf)
nn24 = KNeighborsClassifier(n_neighbors=24).fit(stdpar, clsf)
nn25 = KNeighborsClassifier(n_neighbors=25).fit(stdpar, clsf)
nn26 = KNeighborsClassifier(n_neighbors=26).fit(stdpar, clsf)
nn27 = KNeighborsClassifier(n_neighbors=27).fit(stdpar, clsf)
nn28 = KNeighborsClassifier(n_neighbors=28).fit(stdpar, clsf)
nn29 = KNeighborsClassifier(n_neighbors=29).fit(stdpar, clsf)
nn30 = KNeighborsClassifier(n_neighbors=30).fit(stdpar, clsf)
nn31 = KNeighborsClassifier(n_neighbors=31).fit(stdpar, clsf)
nn32 = KNeighborsClassifier(n_neighbors=32).fit(stdpar, clsf)
nn33 = KNeighborsClassifier(n_neighbors=33).fit(stdpar, clsf)
nn34 = KNeighborsClassifier(n_neighbors=34).fit(stdpar, clsf)
nn35 = KNeighborsClassifier(n_neighbors=35).fit(stdpar, clsf)
nn36 = KNeighborsClassifier(n_neighbors=36).fit(stdpar, clsf)
nn37 = KNeighborsClassifier(n_neighbors=37).fit(stdpar, clsf)
nn38 = KNeighborsClassifier(n_neighbors=38).fit(stdpar, clsf)
nn39 = KNeighborsClassifier(n_neighbors=39).fit(stdpar, clsf)
nn40 = KNeighborsClassifier(n_neighbors=40).fit(stdpar, clsf)
nn41 = KNeighborsClassifier(n_neighbors=41).fit(stdpar, clsf)
nn42 = KNeighborsClassifier(n_neighbors=42).fit(stdpar, clsf)
nn43 = KNeighborsClassifier(n_neighbors=43).fit(stdpar, clsf)
nn44 = KNeighborsClassifier(n_neighbors=44).fit(stdpar, clsf)
nn45 = KNeighborsClassifier(n_neighbors=45).fit(stdpar, clsf)
nn46 = KNeighborsClassifier(n_neighbors=46).fit(stdpar, clsf)
nn47 = KNeighborsClassifier(n_neighbors=47).fit(stdpar, clsf)
nn48 = KNeighborsClassifier(n_neighbors=48).fit(stdpar, clsf)
nn49 = KNeighborsClassifier(n_neighbors=49).fit(stdpar, clsf)
nn50 = KNeighborsClassifier(n_neighbors=50).fit(stdpar, clsf)

# %%
# Кроссвалидация
print('1 ',round(np.mean(cross_val_score(nn1, stdpar, clsf, cv=kf)), 2))
print('2 ',round(np.mean(cross_val_score(nn2, stdpar, clsf, cv=kf)), 2))
print('3 ',round(np.mean(cross_val_score(nn3, stdpar, clsf, cv=kf)), 2))
print('4 ',round(np.mean(cross_val_score(nn4, stdpar, clsf, cv=kf)), 2))
print('5 ',round(np.mean(cross_val_score(nn5, stdpar, clsf, cv=kf)), 2))
print('6 ',round(np.mean(cross_val_score(nn6, stdpar, clsf, cv=kf)), 2))
print('7 ',round(np.mean(cross_val_score(nn7, stdpar, clsf, cv=kf)), 2))
print('8 ',round(np.mean(cross_val_score(nn8, stdpar, clsf, cv=kf)), 2))
print('9 ',round(np.mean(cross_val_score(nn9, stdpar, clsf, cv=kf)), 2))
print('10 ',round(np.mean(cross_val_score(nn10, stdpar, clsf, cv=kf)), 2))
print('11 ',round(np.mean(cross_val_score(nn11, stdpar, clsf, cv=kf)), 2))
print('12 ',round(np.mean(cross_val_score(nn12, stdpar, clsf, cv=kf)), 2))
print('13 ',round(np.mean(cross_val_score(nn13, stdpar, clsf, cv=kf)), 2))
print('14 ',round(np.mean(cross_val_score(nn14, stdpar, clsf, cv=kf)), 2))
print('15 ',round(np.mean(cross_val_score(nn15, stdpar, clsf, cv=kf)), 2))
print('16 ',round(np.mean(cross_val_score(nn16, stdpar, clsf, cv=kf)), 2))
print('17 ',round(np.mean(cross_val_score(nn17, stdpar, clsf, cv=kf)), 2))
print('18 ',round(np.mean(cross_val_score(nn18, stdpar, clsf, cv=kf)), 2))
print('19 ',round(np.mean(cross_val_score(nn19, stdpar, clsf, cv=kf)), 2))
print('20 ',round(np.mean(cross_val_score(nn20, stdpar, clsf, cv=kf)), 2))
print('21 ',round(np.mean(cross_val_score(nn21, stdpar, clsf, cv=kf)), 2))
print('22 ',round(np.mean(cross_val_score(nn22, stdpar, clsf, cv=kf)), 2))
print('23 ',round(np.mean(cross_val_score(nn23, stdpar, clsf, cv=kf)), 2))
print('24 ',round(np.mean(cross_val_score(nn24, stdpar, clsf, cv=kf)), 2))
print('25 ',round(np.mean(cross_val_score(nn25, stdpar, clsf, cv=kf)), 2))
print('26 ',round(np.mean(cross_val_score(nn26, stdpar, clsf, cv=kf)), 2))
print('27 ',round(np.mean(cross_val_score(nn27, stdpar, clsf, cv=kf)), 2))
print('28 ',round(np.mean(cross_val_score(nn28, stdpar, clsf, cv=kf)), 2))
print('29 ',round(np.mean(cross_val_score(nn29, stdpar, clsf, cv=kf)), 2))
print('30 ',round(np.mean(cross_val_score(nn30, stdpar, clsf, cv=kf)), 2))
print('31 ',round(np.mean(cross_val_score(nn31, stdpar, clsf, cv=kf)), 2))
print('32 ',round(np.mean(cross_val_score(nn32, stdpar, clsf, cv=kf)), 2))
print('33 ',round(np.mean(cross_val_score(nn33, stdpar, clsf, cv=kf)), 2))
print('34 ',round(np.mean(cross_val_score(nn34, stdpar, clsf, cv=kf)), 2))
print('35 ',round(np.mean(cross_val_score(nn35, stdpar, clsf, cv=kf)), 2))
print('36 ',round(np.mean(cross_val_score(nn36, stdpar, clsf, cv=kf)), 2))
print('37 ',round(np.mean(cross_val_score(nn37, stdpar, clsf, cv=kf)), 2))
print('38 ',round(np.mean(cross_val_score(nn38, stdpar, clsf, cv=kf)), 2))
print('39 ',round(np.mean(cross_val_score(nn39, stdpar, clsf, cv=kf)), 2))
print('40 ',round(np.mean(cross_val_score(nn40, stdpar, clsf, cv=kf)), 2))
print('41 ',round(np.mean(cross_val_score(nn41, stdpar, clsf, cv=kf)), 2))
print('42 ',round(np.mean(cross_val_score(nn42, stdpar, clsf, cv=kf)), 2))
print('43 ',round(np.mean(cross_val_score(nn43, stdpar, clsf, cv=kf)), 2))
print('44 ',round(np.mean(cross_val_score(nn44, stdpar, clsf, cv=kf)), 2))
print('45 ',round(np.mean(cross_val_score(nn45, stdpar, clsf, cv=kf)), 2))
print('46 ',round(np.mean(cross_val_score(nn46, stdpar, clsf, cv=kf)), 2))
print('47 ',round(np.mean(cross_val_score(nn47, stdpar, clsf, cv=kf)), 2))
print('48 ',round(np.mean(cross_val_score(nn48, stdpar, clsf, cv=kf)), 2))
print('49 ',round(np.mean(cross_val_score(nn49, stdpar, clsf, cv=kf)), 2))
print('50 ',round(np.mean(cross_val_score(nn50, stdpar, clsf, cv=kf)), 2))
# Out:
# 1  0.94
# 2  0.93
# 3  0.96
# 4  0.94
# 5  0.95
# 6  0.95
# 7  0.95
# 8  0.96
# 9  0.96
# 10  0.96
# 11  0.96
# 12  0.96
# 13  0.95
# 14  0.97
# 15  0.97
# 16  0.97
# 17  0.97
# 18  0.97
# 19  0.96
# 20  0.97
# 21  0.96
# 22  0.97
# 23  0.96
# 24  0.96
# 25  0.96
# 26  0.96
# 27  0.96
# 28  0.97
# 29  0.98
# 30  0.96
# 31  0.96
# 32  0.96
# 33  0.97
# 34  0.97
# 35  0.96
# 36  0.96
# 37  0.96
# 38  0.96
# 39  0.96
# 40  0.96
# 41  0.97
# 42  0.96
# 43  0.97
# 44  0.96
# 45  0.97
# 46  0.95
# 47  0.96
# 48  0.95
# 49  0.96
# 50  0.96
