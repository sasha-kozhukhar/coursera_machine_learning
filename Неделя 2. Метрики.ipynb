# %%
import numpy as np
import pandas
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_validation import KFold, cross_val_score
import sklearn.datasets
import sklearn.preprocessing

# %%
data = sklearn.datasets.load_boston()
# data['data' & 'target']
par = data['data']
clsf = data['target']
par1 = sklearn.preprocessing.scale(par, axis=0, with_mean=True, with_std=True)
print(len(par1))
# Out:
# 506

# %%
kf = KFold(len(par1), n_folds = 5, shuffle = True, random_state=42)

# %%
intr = np.linspace(1,10,num=200)
print('step',intr[1]-intr[0])
print(intr)
# Out:
# step 0.0452261306533
# [  1.           1.04522613   1.09045226   1.13567839   1.18090452
#    1.22613065   1.27135678   1.31658291   1.36180905   1.40703518
#    1.45226131   1.49748744   1.54271357   1.5879397    1.63316583
#    1.67839196   1.72361809   1.76884422   1.81407035   1.85929648
#    1.90452261   1.94974874   1.99497487   2.04020101   2.08542714
#    2.13065327   2.1758794    2.22110553   2.26633166   2.31155779
#    2.35678392   2.40201005   2.44723618   2.49246231   2.53768844
#    2.58291457   2.6281407    2.67336683   2.71859296   2.7638191
#    2.80904523   2.85427136   2.89949749   2.94472362   2.98994975
#    3.03517588   3.08040201   3.12562814   3.17085427   3.2160804
#    3.26130653   3.30653266   3.35175879   3.39698492   3.44221106
#    3.48743719   3.53266332   3.57788945   3.62311558   3.66834171
#    3.71356784   3.75879397   3.8040201    3.84924623   3.89447236
#    3.93969849   3.98492462   4.03015075   4.07537688   4.12060302
# ...

# %%
n0 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[0], metric='minkowski').fit(par1, clsf)
n1 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[1], metric='minkowski').fit(par1, clsf)
n2 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[2], metric='minkowski').fit(par1, clsf)
n3 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[3], metric='minkowski').fit(par1, clsf)
n4 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[4], metric='minkowski').fit(par1, clsf)
n5 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[5], metric='minkowski').fit(par1, clsf)
n6 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[6], metric='minkowski').fit(par1, clsf)
n7 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[7], metric='minkowski').fit(par1, clsf)
n8 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[8], metric='minkowski').fit(par1, clsf)
n9 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[9], metric='minkowski').fit(par1, clsf)
n10 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[10], metric='minkowski').fit(par1, clsf)
n11 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[11], metric='minkowski').fit(par1, clsf)
n12 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[12], metric='minkowski').fit(par1, clsf)
n13 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[13], metric='minkowski').fit(par1, clsf)
n14 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[14], metric='minkowski').fit(par1, clsf)
n15 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[15], metric='minkowski').fit(par1, clsf)
n16 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[16], metric='minkowski').fit(par1, clsf)
n17 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[17], metric='minkowski').fit(par1, clsf)
n18 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[18], metric='minkowski').fit(par1, clsf)
n19 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[19], metric='minkowski').fit(par1, clsf)
n20 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[20], metric='minkowski').fit(par1, clsf)
n21 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[21], metric='minkowski').fit(par1, clsf)
n22 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[22], metric='minkowski').fit(par1, clsf)
n23 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[23], metric='minkowski').fit(par1, clsf)
n24 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[24], metric='minkowski').fit(par1, clsf)
n25 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[25], metric='minkowski').fit(par1, clsf)
n26 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[26], metric='minkowski').fit(par1, clsf)
n27 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[27], metric='minkowski').fit(par1, clsf)
n28 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[28], metric='minkowski').fit(par1, clsf)
n29 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[29], metric='minkowski').fit(par1, clsf)
n30 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[30], metric='minkowski').fit(par1, clsf)
n31 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[31], metric='minkowski').fit(par1, clsf)
n32 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[32], metric='minkowski').fit(par1, clsf)
n33 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[33], metric='minkowski').fit(par1, clsf)
n34 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[34], metric='minkowski').fit(par1, clsf)
n35 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[35], metric='minkowski').fit(par1, clsf)
n36 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[36], metric='minkowski').fit(par1, clsf)
n37 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[37], metric='minkowski').fit(par1, clsf)
n38 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[38], metric='minkowski').fit(par1, clsf)
n39 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[39], metric='minkowski').fit(par1, clsf)
n40 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[40], metric='minkowski').fit(par1, clsf)
n41 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[41], metric='minkowski').fit(par1, clsf)
n42 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[42], metric='minkowski').fit(par1, clsf)
n43 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[43], metric='minkowski').fit(par1, clsf)
n44 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[44], metric='minkowski').fit(par1, clsf)
n45 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[45], metric='minkowski').fit(par1, clsf)
n46 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[46], metric='minkowski').fit(par1, clsf)
n47 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[47], metric='minkowski').fit(par1, clsf)
n48 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[48], metric='minkowski').fit(par1, clsf)
n49 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[49], metric='minkowski').fit(par1, clsf)
n50 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[50], metric='minkowski').fit(par1, clsf)
n51 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[51], metric='minkowski').fit(par1, clsf)
n52 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[52], metric='minkowski').fit(par1, clsf)
n53 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[53], metric='minkowski').fit(par1, clsf)
n54 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[54], metric='minkowski').fit(par1, clsf)
n55 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[55], metric='minkowski').fit(par1, clsf)
n56 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[56], metric='minkowski').fit(par1, clsf)
n57 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[57], metric='minkowski').fit(par1, clsf)
n58 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[58], metric='minkowski').fit(par1, clsf)
n59 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[59], metric='minkowski').fit(par1, clsf)
n60 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[60], metric='minkowski').fit(par1, clsf)
n61 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[61], metric='minkowski').fit(par1, clsf)
n62 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[62], metric='minkowski').fit(par1, clsf)
n63 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[63], metric='minkowski').fit(par1, clsf)
n64 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[64], metric='minkowski').fit(par1, clsf)
n65 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[65], metric='minkowski').fit(par1, clsf)
n66 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[66], metric='minkowski').fit(par1, clsf)
n67 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[67], metric='minkowski').fit(par1, clsf)
n68 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[68], metric='minkowski').fit(par1, clsf)
n69 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[69], metric='minkowski').fit(par1, clsf)
n70 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[70], metric='minkowski').fit(par1, clsf)
n71 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[71], metric='minkowski').fit(par1, clsf)
n72 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[72], metric='minkowski').fit(par1, clsf)
n73 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[73], metric='minkowski').fit(par1, clsf)
n74 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[74], metric='minkowski').fit(par1, clsf)
n75 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[75], metric='minkowski').fit(par1, clsf)
n76 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[76], metric='minkowski').fit(par1, clsf)
n77 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[77], metric='minkowski').fit(par1, clsf)
n78 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[78], metric='minkowski').fit(par1, clsf)
n79 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[79], metric='minkowski').fit(par1, clsf)
n80 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[80], metric='minkowski').fit(par1, clsf)
n81 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[81], metric='minkowski').fit(par1, clsf)
n82 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[82], metric='minkowski').fit(par1, clsf)
n83 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[83], metric='minkowski').fit(par1, clsf)
n84 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[84], metric='minkowski').fit(par1, clsf)
n85 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[85], metric='minkowski').fit(par1, clsf)
n86 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[86], metric='minkowski').fit(par1, clsf)
n87 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[87], metric='minkowski').fit(par1, clsf)
n88 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[88], metric='minkowski').fit(par1, clsf)
n89 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[89], metric='minkowski').fit(par1, clsf)
n90 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[90], metric='minkowski').fit(par1, clsf)
n91 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[91], metric='minkowski').fit(par1, clsf)
n92 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[92], metric='minkowski').fit(par1, clsf)
n93 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[93], metric='minkowski').fit(par1, clsf)
n94 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[94], metric='minkowski').fit(par1, clsf)
n95 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[95], metric='minkowski').fit(par1, clsf)
n96 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[96], metric='minkowski').fit(par1, clsf)
n97 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[97], metric='minkowski').fit(par1, clsf)
n98 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[98], metric='minkowski').fit(par1, clsf)
n99 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[99], metric='minkowski').fit(par1, clsf)
n100 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[100], metric='minkowski').fit(par1, clsf)
n101 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[101], metric='minkowski').fit(par1, clsf)
n102 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[102], metric='minkowski').fit(par1, clsf)
n103 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[103], metric='minkowski').fit(par1, clsf)
n104 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[104], metric='minkowski').fit(par1, clsf)
n105 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[105], metric='minkowski').fit(par1, clsf)
n106 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[106], metric='minkowski').fit(par1, clsf)
n107 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[107], metric='minkowski').fit(par1, clsf)
n108 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[108], metric='minkowski').fit(par1, clsf)
n109 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[109], metric='minkowski').fit(par1, clsf)
n110 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[110], metric='minkowski').fit(par1, clsf)
n111 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[111], metric='minkowski').fit(par1, clsf)
n112 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[112], metric='minkowski').fit(par1, clsf)
n113 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[113], metric='minkowski').fit(par1, clsf)
n114 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[114], metric='minkowski').fit(par1, clsf)
n115 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[115], metric='minkowski').fit(par1, clsf)
n116 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[116], metric='minkowski').fit(par1, clsf)
n117 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[117], metric='minkowski').fit(par1, clsf)
n118 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[118], metric='minkowski').fit(par1, clsf)
n119 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[119], metric='minkowski').fit(par1, clsf)
n120 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[120], metric='minkowski').fit(par1, clsf)
n121 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[121], metric='minkowski').fit(par1, clsf)
n122 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[122], metric='minkowski').fit(par1, clsf)
n123 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[123], metric='minkowski').fit(par1, clsf)
n124 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[124], metric='minkowski').fit(par1, clsf)
n125 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[125], metric='minkowski').fit(par1, clsf)
n126 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[126], metric='minkowski').fit(par1, clsf)
n127 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[127], metric='minkowski').fit(par1, clsf)
n128 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[128], metric='minkowski').fit(par1, clsf)
n129 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[129], metric='minkowski').fit(par1, clsf)
n130 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[130], metric='minkowski').fit(par1, clsf)
n131 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[131], metric='minkowski').fit(par1, clsf)
n132 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[132], metric='minkowski').fit(par1, clsf)
n133 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[133], metric='minkowski').fit(par1, clsf)
n134 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[134], metric='minkowski').fit(par1, clsf)
n135 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[135], metric='minkowski').fit(par1, clsf)
n136 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[136], metric='minkowski').fit(par1, clsf)
n137 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[137], metric='minkowski').fit(par1, clsf)
n138 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[138], metric='minkowski').fit(par1, clsf)
n139 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[139], metric='minkowski').fit(par1, clsf)
n140 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[140], metric='minkowski').fit(par1, clsf)
n141 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[141], metric='minkowski').fit(par1, clsf)
n142 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[142], metric='minkowski').fit(par1, clsf)
n143 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[143], metric='minkowski').fit(par1, clsf)
n144 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[144], metric='minkowski').fit(par1, clsf)
n145 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[145], metric='minkowski').fit(par1, clsf)
n146 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[146], metric='minkowski').fit(par1, clsf)
n147 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[147], metric='minkowski').fit(par1, clsf)
n148 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[148], metric='minkowski').fit(par1, clsf)
n149 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[149], metric='minkowski').fit(par1, clsf)
n150 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[150], metric='minkowski').fit(par1, clsf)
n151 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[151], metric='minkowski').fit(par1, clsf)
n152 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[152], metric='minkowski').fit(par1, clsf)
n153 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[153], metric='minkowski').fit(par1, clsf)
n154 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[154], metric='minkowski').fit(par1, clsf)
n155 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[155], metric='minkowski').fit(par1, clsf)
n156 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[156], metric='minkowski').fit(par1, clsf)
n157 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[157], metric='minkowski').fit(par1, clsf)
n158 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[158], metric='minkowski').fit(par1, clsf)
n159 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[159], metric='minkowski').fit(par1, clsf)
n160 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[160], metric='minkowski').fit(par1, clsf)
n161 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[161], metric='minkowski').fit(par1, clsf)
n162 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[162], metric='minkowski').fit(par1, clsf)
n163 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[163], metric='minkowski').fit(par1, clsf)
n164 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[164], metric='minkowski').fit(par1, clsf)
n165 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[165], metric='minkowski').fit(par1, clsf)
n166 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[166], metric='minkowski').fit(par1, clsf)
n167 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[167], metric='minkowski').fit(par1, clsf)
n168 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[168], metric='minkowski').fit(par1, clsf)
n169 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[169], metric='minkowski').fit(par1, clsf)
n170 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[170], metric='minkowski').fit(par1, clsf)
n171 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[171], metric='minkowski').fit(par1, clsf)
n172 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[172], metric='minkowski').fit(par1, clsf)
n173 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[173], metric='minkowski').fit(par1, clsf)
n174 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[174], metric='minkowski').fit(par1, clsf)
n175 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[175], metric='minkowski').fit(par1, clsf)
n176 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[176], metric='minkowski').fit(par1, clsf)
n177 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[177], metric='minkowski').fit(par1, clsf)
n178 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[178], metric='minkowski').fit(par1, clsf)
n179 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[179], metric='minkowski').fit(par1, clsf)
n180 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[180], metric='minkowski').fit(par1, clsf)
n181 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[181], metric='minkowski').fit(par1, clsf)
n182 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[182], metric='minkowski').fit(par1, clsf)
n183 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[183], metric='minkowski').fit(par1, clsf)
n184 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[184], metric='minkowski').fit(par1, clsf)
n185 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[185], metric='minkowski').fit(par1, clsf)
n186 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[186], metric='minkowski').fit(par1, clsf)
n187 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[187], metric='minkowski').fit(par1, clsf)
n188 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[188], metric='minkowski').fit(par1, clsf)
n189 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[189], metric='minkowski').fit(par1, clsf)
n190 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[190], metric='minkowski').fit(par1, clsf)
n191 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[191], metric='minkowski').fit(par1, clsf)
n192 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[192], metric='minkowski').fit(par1, clsf)
n193 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[193], metric='minkowski').fit(par1, clsf)
n194 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[194], metric='minkowski').fit(par1, clsf)
n195 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[195], metric='minkowski').fit(par1, clsf)
n196 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[196], metric='minkowski').fit(par1, clsf)
n197 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[197], metric='minkowski').fit(par1, clsf)
n198 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[198], metric='minkowski').fit(par1, clsf)
n199 = sklearn.neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance', p=intr[199], metric='minkowski').fit(par1, clsf)

# %%
print('intr[0] ', round(np.mean(cross_val_score(n0, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[1] ', round(np.mean(cross_val_score(n1, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[2] ', round(np.mean(cross_val_score(n2, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[3] ', round(np.mean(cross_val_score(n3, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[4] ', round(np.mean(cross_val_score(n4, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[5] ', round(np.mean(cross_val_score(n5, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[6] ', round(np.mean(cross_val_score(n6, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[7] ', round(np.mean(cross_val_score(n7, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[8] ', round(np.mean(cross_val_score(n8, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[9] ', round(np.mean(cross_val_score(n9, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[10] ', round(np.mean(cross_val_score(n10, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[11] ', round(np.mean(cross_val_score(n11, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[12] ', round(np.mean(cross_val_score(n12, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[13] ', round(np.mean(cross_val_score(n13, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[14] ', round(np.mean(cross_val_score(n14, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[15] ', round(np.mean(cross_val_score(n15, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[16] ', round(np.mean(cross_val_score(n16, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[17] ', round(np.mean(cross_val_score(n17, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[18] ', round(np.mean(cross_val_score(n18, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[19] ', round(np.mean(cross_val_score(n19, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[20] ', round(np.mean(cross_val_score(n20, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[21] ', round(np.mean(cross_val_score(n21, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[22] ', round(np.mean(cross_val_score(n22, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[23] ', round(np.mean(cross_val_score(n23, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[24] ', round(np.mean(cross_val_score(n24, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[25] ', round(np.mean(cross_val_score(n25, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[26] ', round(np.mean(cross_val_score(n26, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[27] ', round(np.mean(cross_val_score(n27, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[28] ', round(np.mean(cross_val_score(n28, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[29] ', round(np.mean(cross_val_score(n29, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[30] ', round(np.mean(cross_val_score(n30, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[31] ', round(np.mean(cross_val_score(n31, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[32] ', round(np.mean(cross_val_score(n32, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[33] ', round(np.mean(cross_val_score(n33, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[34] ', round(np.mean(cross_val_score(n34, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[35] ', round(np.mean(cross_val_score(n35, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[36] ', round(np.mean(cross_val_score(n36, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[37] ', round(np.mean(cross_val_score(n37, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[38] ', round(np.mean(cross_val_score(n38, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[39] ', round(np.mean(cross_val_score(n39, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[40] ', round(np.mean(cross_val_score(n40, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[41] ', round(np.mean(cross_val_score(n41, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[42] ', round(np.mean(cross_val_score(n42, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[43] ', round(np.mean(cross_val_score(n43, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[44] ', round(np.mean(cross_val_score(n44, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[45] ', round(np.mean(cross_val_score(n45, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[46] ', round(np.mean(cross_val_score(n46, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[47] ', round(np.mean(cross_val_score(n47, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[48] ', round(np.mean(cross_val_score(n48, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[49] ', round(np.mean(cross_val_score(n49, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[50] ', round(np.mean(cross_val_score(n50, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[51] ', round(np.mean(cross_val_score(n51, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[52] ', round(np.mean(cross_val_score(n52, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[53] ', round(np.mean(cross_val_score(n53, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[54] ', round(np.mean(cross_val_score(n54, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[55] ', round(np.mean(cross_val_score(n55, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[56] ', round(np.mean(cross_val_score(n56, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[57] ', round(np.mean(cross_val_score(n57, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[58] ', round(np.mean(cross_val_score(n58, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[59] ', round(np.mean(cross_val_score(n59, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[60] ', round(np.mean(cross_val_score(n60, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[61] ', round(np.mean(cross_val_score(n61, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[62] ', round(np.mean(cross_val_score(n62, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[63] ', round(np.mean(cross_val_score(n63, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[64] ', round(np.mean(cross_val_score(n64, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[65] ', round(np.mean(cross_val_score(n65, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[66] ', round(np.mean(cross_val_score(n66, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[67] ', round(np.mean(cross_val_score(n67, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[68] ', round(np.mean(cross_val_score(n68, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[69] ', round(np.mean(cross_val_score(n69, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[70] ', round(np.mean(cross_val_score(n70, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[71] ', round(np.mean(cross_val_score(n71, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[72] ', round(np.mean(cross_val_score(n72, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[73] ', round(np.mean(cross_val_score(n73, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[74] ', round(np.mean(cross_val_score(n74, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[75] ', round(np.mean(cross_val_score(n75, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[76] ', round(np.mean(cross_val_score(n76, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[77] ', round(np.mean(cross_val_score(n77, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[78] ', round(np.mean(cross_val_score(n78, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[79] ', round(np.mean(cross_val_score(n79, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[80] ', round(np.mean(cross_val_score(n80, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[81] ', round(np.mean(cross_val_score(n81, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[82] ', round(np.mean(cross_val_score(n82, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[83] ', round(np.mean(cross_val_score(n83, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[84] ', round(np.mean(cross_val_score(n84, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[85] ', round(np.mean(cross_val_score(n85, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[86] ', round(np.mean(cross_val_score(n86, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[87] ', round(np.mean(cross_val_score(n87, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[88] ', round(np.mean(cross_val_score(n88, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[89] ', round(np.mean(cross_val_score(n89, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[90] ', round(np.mean(cross_val_score(n90, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[91] ', round(np.mean(cross_val_score(n91, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[92] ', round(np.mean(cross_val_score(n92, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[93] ', round(np.mean(cross_val_score(n93, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[94] ', round(np.mean(cross_val_score(n94, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[95] ', round(np.mean(cross_val_score(n95, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[96] ', round(np.mean(cross_val_score(n96, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[97] ', round(np.mean(cross_val_score(n97, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[98] ', round(np.mean(cross_val_score(n98, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[99] ', round(np.mean(cross_val_score(n99, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[100] ', round(np.mean(cross_val_score(n100, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[101] ', round(np.mean(cross_val_score(n101, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[102] ', round(np.mean(cross_val_score(n102, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[103] ', round(np.mean(cross_val_score(n103, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[104] ', round(np.mean(cross_val_score(n104, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[105] ', round(np.mean(cross_val_score(n105, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[106] ', round(np.mean(cross_val_score(n106, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[107] ', round(np.mean(cross_val_score(n107, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[108] ', round(np.mean(cross_val_score(n108, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[109] ', round(np.mean(cross_val_score(n109, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[110] ', round(np.mean(cross_val_score(n110, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[111] ', round(np.mean(cross_val_score(n111, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[112] ', round(np.mean(cross_val_score(n112, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[113] ', round(np.mean(cross_val_score(n113, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[114] ', round(np.mean(cross_val_score(n114, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[115] ', round(np.mean(cross_val_score(n115, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[116] ', round(np.mean(cross_val_score(n116, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[117] ', round(np.mean(cross_val_score(n117, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[118] ', round(np.mean(cross_val_score(n118, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[119] ', round(np.mean(cross_val_score(n119, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[120] ', round(np.mean(cross_val_score(n120, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[121] ', round(np.mean(cross_val_score(n121, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[122] ', round(np.mean(cross_val_score(n122, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[123] ', round(np.mean(cross_val_score(n123, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[124] ', round(np.mean(cross_val_score(n124, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[125] ', round(np.mean(cross_val_score(n125, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[126] ', round(np.mean(cross_val_score(n126, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[127] ', round(np.mean(cross_val_score(n127, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[128] ', round(np.mean(cross_val_score(n128, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[129] ', round(np.mean(cross_val_score(n129, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[130] ', round(np.mean(cross_val_score(n130, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[131] ', round(np.mean(cross_val_score(n131, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[132] ', round(np.mean(cross_val_score(n132, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[133] ', round(np.mean(cross_val_score(n133, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[134] ', round(np.mean(cross_val_score(n134, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[135] ', round(np.mean(cross_val_score(n135, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[136] ', round(np.mean(cross_val_score(n136, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[137] ', round(np.mean(cross_val_score(n137, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[138] ', round(np.mean(cross_val_score(n138, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[139] ', round(np.mean(cross_val_score(n139, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[140] ', round(np.mean(cross_val_score(n140, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[141] ', round(np.mean(cross_val_score(n141, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[142] ', round(np.mean(cross_val_score(n142, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[143] ', round(np.mean(cross_val_score(n143, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[144] ', round(np.mean(cross_val_score(n144, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[145] ', round(np.mean(cross_val_score(n145, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[146] ', round(np.mean(cross_val_score(n146, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[147] ', round(np.mean(cross_val_score(n147, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[148] ', round(np.mean(cross_val_score(n148, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[149] ', round(np.mean(cross_val_score(n149, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[150] ', round(np.mean(cross_val_score(n150, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[151] ', round(np.mean(cross_val_score(n151, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[152] ', round(np.mean(cross_val_score(n152, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[153] ', round(np.mean(cross_val_score(n153, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[154] ', round(np.mean(cross_val_score(n154, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[155] ', round(np.mean(cross_val_score(n155, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[156] ', round(np.mean(cross_val_score(n156, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[157] ', round(np.mean(cross_val_score(n157, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[158] ', round(np.mean(cross_val_score(n158, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[159] ', round(np.mean(cross_val_score(n159, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[160] ', round(np.mean(cross_val_score(n160, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[161] ', round(np.mean(cross_val_score(n161, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[162] ', round(np.mean(cross_val_score(n162, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[163] ', round(np.mean(cross_val_score(n163, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[164] ', round(np.mean(cross_val_score(n164, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[165] ', round(np.mean(cross_val_score(n165, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[166] ', round(np.mean(cross_val_score(n166, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[167] ', round(np.mean(cross_val_score(n167, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[168] ', round(np.mean(cross_val_score(n168, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[169] ', round(np.mean(cross_val_score(n169, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[170] ', round(np.mean(cross_val_score(n170, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[171] ', round(np.mean(cross_val_score(n171, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[172] ', round(np.mean(cross_val_score(n172, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[173] ', round(np.mean(cross_val_score(n173, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[174] ', round(np.mean(cross_val_score(n174, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[175] ', round(np.mean(cross_val_score(n175, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[176] ', round(np.mean(cross_val_score(n176, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[177] ', round(np.mean(cross_val_score(n177, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[178] ', round(np.mean(cross_val_score(n178, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[179] ', round(np.mean(cross_val_score(n179, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[180] ', round(np.mean(cross_val_score(n180, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[181] ', round(np.mean(cross_val_score(n181, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[182] ', round(np.mean(cross_val_score(n182, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[183] ', round(np.mean(cross_val_score(n183, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[184] ', round(np.mean(cross_val_score(n184, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[185] ', round(np.mean(cross_val_score(n185, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[186] ', round(np.mean(cross_val_score(n186, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[187] ', round(np.mean(cross_val_score(n187, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[188] ', round(np.mean(cross_val_score(n188, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[189] ', round(np.mean(cross_val_score(n189, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[190] ', round(np.mean(cross_val_score(n190, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[191] ', round(np.mean(cross_val_score(n191, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[192] ', round(np.mean(cross_val_score(n192, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[193] ', round(np.mean(cross_val_score(n193, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[194] ', round(np.mean(cross_val_score(n194, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[195] ', round(np.mean(cross_val_score(n195, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[196] ', round(np.mean(cross_val_score(n196, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[197] ', round(np.mean(cross_val_score(n197, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[198] ', round(np.mean(cross_val_score(n198, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
print('intr[199] ', round(np.mean(cross_val_score(n199, par, clsf, scoring='mean_squared_error', cv=kf)), 2))
# Out:
# intr[0]  -29.8
# intr[1]  -30.22
# intr[2]  -30.42
# intr[3]  -30.98
# intr[4]  -31.22
# intr[5]  -31.27
# intr[6]  -31.92
# intr[7]  -32.31
# intr[8]  -32.9
# intr[9]  -33.73
# intr[10]  -34.3
# intr[11]  -34.41
# intr[12]  -34.47
# intr[13]  -34.41
# intr[14]  -34.78
# intr[15]  -34.87
# intr[16]  -34.99
# intr[17]  -35.35
# intr[18]  -35.79
# intr[19]  -35.82
# intr[20]  -35.99
# intr[21]  -36.33
# intr[22]  -36.39
# intr[23]  -36.58
# intr[24]  -37.12
# intr[25]  -37.35
# intr[26]  -37.41
# intr[27]  -37.53
# intr[28]  -37.96
# intr[29]  -37.87
# intr[30]  -38.21
# intr[31]  -38.33
# intr[32]  -38.65
# intr[33]  -38.82
# intr[34]  -38.84
# intr[35]  -38.81
# intr[36]  -38.86
# intr[37]  -38.93
# intr[38]  -38.96
# intr[39]  -39.05
# intr[40]  -39.38
# intr[41]  -39.43
# intr[42]  -39.28
# intr[43]  -39.32
# intr[44]  -39.35
# intr[45]  -39.48
# intr[46]  -39.69
# intr[47]  -39.7
# intr[48]  -40.03
# intr[49]  -40.05
# intr[50]  -40.08
# intr[51]  -40.12
# intr[52]  -40.43
# ...
